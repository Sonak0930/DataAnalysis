# %%
import pandas as pd

titanic=pd.read_csv('data/titanic.csv')

titanic['Fare'].describe()
# Out:
# count    891.000000
# mean      32.204208
# std       49.693429
# min        0.000000
# 25%        7.910400
# 50%       14.454200
# 75%       31.000000
# max      512.329200
# Name: Fare, dtype: float64

# %%
import matplotlib.pyplot as plt

plt.boxplot(x='Fare',data=titanic)
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x1c5da35fb10>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x1c5da35fd90>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x1c5da35f9d0>],
#  'medians': [<matplotlib.lines.Line2D at 0x1c5da280050>],
#  'fliers': [<matplotlib.lines.Line2D at 0x1c5da280190>],
#  'means': []}

# %%
import numpy as np
import seaborn as sns

z_score=np.abs(titanic['Fare']-titanic['Fare'].mean())/titanic['Fare'].std()

titanic_z =titanic[z_score<2.5]

sns.kdeplot(x='Fare', data=titanic_z)
# Out:
# <Axes: xlabel='Fare', ylabel='Density'>

# %%
titanic['Pclass'].value_counts()
titanic['Pclass'].value_counts()/len(titanic['Pclass'])
# Out:
# Pclass
# 3    0.551066
# 1    0.242424
# 2    0.206510
# Name: count, dtype: float64

# %%
titanic['Pclass']

sns.countplot(x='Pclass',data=titanic)
# Out:
# <Axes: xlabel='Pclass', ylabel='count'>

# %%
oz=pd.read_csv('data/ozone.csv')
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 153 entries, 0 to 152
# Data columns (total 5 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   Ozone    153 non-null    int64
#  1   Solar.R  146 non-null    float64
#  2   Wind     153 non-null    float64
#  3   Temp     153 non-null    int64
#  4   Date     153 non-null    str
# dtypes: float64(2), int64(2), str(1)
# memory usage: 6.1 KB
