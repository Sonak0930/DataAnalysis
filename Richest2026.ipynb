# %%
import pandas as pd

# %%
mb=pd.read_csv('Richest2026.csv')
mb['Industry'].value_counts()
# Out:
# Industry
# Technology          29
# Finance             15
# Fashion & Retail    13
# Diversified         11
# Food & Beverage      6
# Metals & Mining      5
# Manufacturing        5
# Logistics            4
# Automotive           3
# Healthcare           3
# Construction         2
# Real Estate          2
# Telecom              1
# Gambling             1
# Name: count, dtype: int64

# %% [markdown]
# 백만장자중에는 테크 비중이 크다.

# %%
from importlib import reload
import matplotlib as mpl
import matplotlib.pyplot as plt
reload(mpl)
reload(plt)
# Out:
# <module 'matplotlib.pyplot' from 'c:\\Users\\samsung\\.venv\\Lib\\site-packages\\matplotlib\\pyplot.py'>

# %%
import matplotlib.pyplot as plt



y=mb['Net_Worth_USD_Billion']

plt.style.use('dark_background')
plt.xlabel('rank of the richest',color='white')
plt.ylabel('Net worth',color='white')


plt.title("Top 100 worth of the richest in 2026")

plt.hist(y,100)
plt.tight_layout() 
plt.show()

[y]
# Out:
# [0     841.1
#  1     272.4
#  2     251.3
#  3     244.3
#  4     229.3
#        ...
#  95     21.5
#  96     21.2
#  97     20.8
#  98     20.5
#  99     20.2
#  Name: Net_Worth_USD_Billion, Length: 100, dtype: float64]
