# %%
import pandas as pd

# %%
titanic = pd.read_csv('data/titanic.csv')
titanic

#EDA과정: 일단 전혀 관련 없는 데이터만 지우고,
#나머지는 살려두기.

#타이타닉 생존자  캐빈, 지역,나이,가족 등과 
#배의 형태를 같이 보여줘도 좋을 거 같긴 하다.

#근데 나이,가족은 비주얼라이제이션을 어떻게 해야하지?
#배 모양과는 큰 관련이.. 있을 수도 있겠다.
#일단 그려보면 알 거 같은데.



#Embarked 승차 선착장 이름
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
titanic.info()

#dtype이 내가 생각한게 맞는지 확인하기.
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    str
#  4   Sex          891 non-null    str
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    str
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    str
#  11  Embarked     889 non-null    str
# dtypes: float64(2), int64(5), str(5)
# memory usage: 83.7 KB

# %%
import 

titanic['Age'].describe()
#nan 누락값 제외.
#평균이니까 젊은 청년들이 많이 탔구나.
#표준편차. 
plt.plot(titanic['Age'])

# %%
from importlib import reload
import matplotlib as mpl
import matplotlib.pyplot as plt
reload(mpl)
reload(plt)
# Out:
# <module 'matplotlib.pyplot' from 'c:\\Users\\samsung\\.venv\\Lib\\site-packages\\matplotlib\\pyplot.py'>

# %%
import matplotlib.pyplot


x=titanic['Pclass']
y=titanic['Survived']

plt.subplot(1,1,1)

plt.plot(x)

# %%
titanic['Age'].describe()

#50%값이 mean과 비슷하다= 편향되지 않고 평균 근처에 고르게 분포.

#최대값은 80이고,
# Out:
# count    714.000000
# mean      29.699118
# std       14.526497
# min        0.420000
# 25%       20.125000
# 50%       28.000000
# 75%       38.000000
# max       80.000000
# Name: Age, dtype: float64

# %%
import matplotlib.pyplot as plt
import seaborn as sb
plt.subplot(3,1,1)
sb.histplot(data = titanic, x = 'Age',kde=True)

plt.subplot(3,1,2)
sb.boxplot(data = titanic, x = 'Age')
# Out:
# <Axes: xlabel='Age'>

# %%
import matplotlib.pyplot as plt
import seaborn as sb

plt.subplot(3,1,1)
sb.histplot(data=titanic,x='Age')
plt.subplot(3,1,2)
sb.boxplot(data=titanic,x='Age')
plt.subplot(3,1,3)
sb.violinplot(data=titanic,x='Age')
# Out:
# <Axes: xlabel='Age'>

# %%
titanic['Fare'].describe()
# Out:
# count    891.000000
# mean      32.204208
# std       49.693429
# min        0.000000
# 25%        7.910400
# 50%       14.454200
# 75%       31.000000
# max      512.329200
# Name: Fare, dtype: float64

# %% [markdown]
# 요금의 범위를 봤을때, 대부분 30달러 미만을 내고 탑승했다.
#
# 0달러인 사람들의 거주지를 모아서 확인해 봤을때,
# T칸에 탑승한 사람들은 타이타닉 선원으로 추측된다.
# (Transportation:수송)칸에 탔을 경우, 아마 선원들은
# 짐칸에서 머물렀을 것으로 보인다.
#
# 돈을 많이 낸 사람들의 이유?
# -> 아마 스위트룸이 아니었을까?
# -> 장거리 운항이 아니었을까?

# %%
sb.histplot(data=titanic['Fare'],kde=True)
# Out:
# <Axes: xlabel='Fare', ylabel='Count'>

# %%
import numpy as np
IQR= titanic['Fare'].quantile(0.75)-titanic['Fare'].quantile(0.25)

q1=titanic['Fare'].quantile(0.25)
q2=titanic['Fare'].quantile(0.75)

sb.kdeplot(x=[q2,q1])

#med=titanic['Fare'].median()
#sigma=titanic['Fare'].std()


#quant= np.array([-1.0,-0.75,-0.5,-0.25,0,0.25,0.5,0.75,1.0])
#quant


#quantiles= np.quantile(titanic['Fare'],np.array([-4*sigma,-3*sigma,-2*sigma,-1*sigma,
#0*sigma,1*sigma,2*sigma,3*sigma,4*sigma]))
#plt.xticks(q1)
# Out:
# <Axes: ylabel='Density'>

# %% [markdown]
# #whisker=수염, - - 로 표시된 값.

# %%
box=plt.boxplot(titanic['Fare'])

print(box['whiskers'][0].get_ydata())
print(box['whiskers'][1].get_ydata())
# Out:
# [7.9104 0.    ]
# [31. 65.]
# np.float64(65.0)

# %%
modifiedFair=titanic[titanic['Fare']<65.6344]['Fare']
plt.boxplot(x=modifiedFair)
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x2786451f7a0>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x2786451cb30>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x2786451cf50>],
#  'medians': [<matplotlib.lines.Line2D at 0x2786451ef30>],
#  'fliers': [<matplotlib.lines.Line2D at 0x2786451c230>],
#  'means': []}

# %% [markdown]
# 중앙값이 7달러 -> 14달러로 바뀌었다.

# %%
p_cnt=titanic['Pclass'].value_counts()
#plt.Figure(figsize=(7,3))
titanic['Sex'].value_counts()

titanic['Survived'].value_counts()
# Out:
# Survived
# 0    549
# 1    342
# Name: count, dtype: int64

# %% [markdown]
# 두 집단의 크기가 비슷할 수록 편향이 적고 좋은 데이터다.
#
# X:300
# O:10
#
# -> X가 더 많으니까, X를 기준으로 학습을 진행한다.
# -> 정상적인 학습이 이루어지지 않음.
#
# 제조,iot 데이터= 99% 이상이 정상 데이터.
# -> 비율을 맞춰주던지, 아님 다른 학습 방법을 찾던지.
#
# 방법1. 사망한 생존자를 랜덤하게 200명 지우기.
# 데이터가 충분한 경우만..

# %%
titanic['Pclass'].value_counts()
titanic['Pclass'].value_counts()/len(titanic['Pclass'])

titanic['Survived'].value_counts()/titanic.shape[0]
# Out:
# count      891
# unique       2
# top       male
# freq       577
# Name: Sex, dtype: object

# %%
titanic['Sex'].describe()
titanic['Sex'].unique()
# Out:
# <StringArray>
# ['male', 'female']
# Length: 2, dtype: str

# %%
titanic['Pclass'].value_counts()
# Out:
# Pclass
# 3    491
# 1    216
# 2    184
# Name: count, dtype: int64

# %%
sb.countplot(data=titanic,x='Pclass')
# Out:
# <Axes: xlabel='Pclass', ylabel='count'>

# %%
plt.pie(p_cnt.values,labels=p_cnt.index)

# %%
air=pd.read_csv('data/ozone.csv')
air.head()

#float도 .0인지, .0이면 int형으로 변경해주기.
# Out:
#    Ozone  Solar.R  Wind  Temp        Date
# 0     41    190.0   7.4    67  1973-05-01
# 1     36    118.0   8.0    72  1973-05-02
# 2     12    149.0  12.6    74  1973-05-03
# 3     18    313.0  11.5    62  1973-05-04
# 4     19      NaN  14.3    56  1973-05-05

# %%
sb.scatterplot(x='Temp',y='Ozone',data=air)
# Out:
# <Axes: xlabel='Temp', ylabel='Ozone'>

# %% [markdown]
# 그래프마다 적합한 데이터가 어느정도 정해져있구나.
