# %%
import pandas as pd
import seaborn as sb
air=pd.read_csv('data/ozone.csv')
air.head()
# Out:
#    Ozone  Solar.R  Wind  Temp        Date
# 0     41    190.0   7.4    67  1973-05-01
# 1     36    118.0   8.0    72  1973-05-02
# 2     12    149.0  12.6    74  1973-05-03
# 3     18    313.0  11.5    62  1973-05-04
# 4     19      NaN  14.3    56  1973-05-05

# %%
import matplotlib.pyplot as plt

plt.scatter('Temp','Ozone',data=air)

# %%
sb.pairplot(air)

#와~ 너무좋아요

# %%
titanic=pd.read_csv('data/titanic.csv')
sb.pairplot(titanic)

# %%
sb.scatterplot(x='Fare',y='Fare',data=titanic)
# Out:
# <Axes: xlabel='Fare', ylabel='Fare'>

# %%
corr=air.corr(numeric_only=True)

# %% [markdown]
# 오존이 많다 = 고도가 높다= 바람이 덜 분다 = 태양과 가까워지면서 온도가 올라간다..? 근데 태양 복사 에너지의 양은 어느정도 연관성이 있나보다.
#
# 온도가 올라가면 바람이 덜 불겠구나.
#
# 독립변수들 간의 연관관계가 중요한 이유..?
# -> 두 변수들은 independent =서로 영향이 적어야 한다.
#
# 예) a=화씨온도, b=섭씨온도
#
# 독립적이지 않은 변수 2개(중복된 데이터)를 넣으면 예측 성능이 떨어진다.
# -> 그래프를 그리기 전에 correlation 분석을 해서 중복된 값이 있는지 (1,-1) 확인해야한다.

# %%
sb.heatmap(corr,vmin=-1,vmax=1,annot=True)

#기본: 자료의 최대,최소 범위를 축으로 표현
#vmin, vmax 설정 -> custom min/max range set
# Out:
# <Axes: >

# %%
titanic=sb.load_dataset('titanic')

sb.barplot(x='class',y='sibsp',data=titanic)

#titanic.corr(numeric_only=True)


titanic['sibsp']
# Out:
# 0      1
# 1      1
# 2      0
# 3      1
# 4      0
#       ..
# 886    0
# 887    0
# 888    1
# 889    0
# 890    0
# Name: sibsp, Length: 891, dtype: int64

# %% [markdown]
# | -> 신뢰구간을 확장했을때 두 구간이 겹칠 경우 -> 두 집단의 평균의 차이가 없다 -> sibsp와 class는 큰 차이가 없다.

# %%
plt.figure(figsize=(4,2))
sb.barplot(x='sex',y='age',data=titanic)
# Out:
# <Axes: xlabel='sex', ylabel='age'>

# %% [markdown]
# 성별과 나이는 큰 관련이 없다.

# %% [markdown]
# 예측과 분석의 차이.
#
# 분석: x,y 1:1로 분석(특히 회귀분석)
# 예측: (x1..xn):y로 예측.
